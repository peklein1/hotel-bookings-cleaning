# %%
import pandas as pd

# %%
hotel_bookings = pd.read_csv(r"C:\Users\pek43\Projects\hotel-bookings-cleaning\data\hotel_bookings.csv")

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\pek43\\projects\\hotel-bookings-cleaning\\notebooks'

# %%
hotel_bookings = pd.read_csv(r"C:\Users\pek43\Projects\hotel-bookings-cleaning\data\hotel_bookings.csv")

# %%
import pandas as pd

pd = pd.read_csv("../data/hotel_bookings.csv")
